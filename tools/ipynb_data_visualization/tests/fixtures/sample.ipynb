# %% [markdown]
# # Sample notebook
#
# A tiny fixture used by tests.

# %%
import pandas as pd

df = pd.DataFrame({'name': ['Alice', 'Bob', 'Carol'], 'score': [10, 20, 30]})

# %% [markdown]
# ## Second section

# %%
result_df = df[df['score'] >= 20].copy()
result_df['rank'] = [1, 2]

# %%
summary = result_df.describe()
